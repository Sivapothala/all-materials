# %% [markdown]
# ### AI
#
# -  to create an application which can perform its own task without any human intervention.
# - Eg :
#     - Netflix movie recomendation.
#     - autonomous cars.
#
# - Machine learning
#     -  a branch of artificial intelligence which is concerned with the development of algorithms that can learn from
#     - It provides the stats to analyse, visualize, predict or forecasting.
# - Deep Learning
#     - Mimic the Human Brain.
#     - Multi-layered Neural Network.

# %% [markdown]
# ### Types of Machine Learning
# - Supervised ML
#     - task is to predict the house price.
#         - size of the house - indep
#         - no of Rooms. - indep
#         - Prices. - dependent
#     - Output/Dependent Feature
#     - Regression (continuous values)
#     - Classification (Discrete Values/Categorical Values)
#         - binary Classification
#         - multi class Classification
#     - Algorithms :
#         - Linear
#         - Ridge
#         - Lasso
#         - ElasticNet
#         - Logestic Regression
#         - Both Classification & Regression
#             - Decision Tree
#             - Random Forest
#             - AdaBoost
#             - XgBoost
#         - Gradient Boosting
# - Unsuper vised Classification.
#     - e.g : Customer Segmaentation.
#     - there is no output feature.
#     - Algorithms :
#         - k Means
#         - Hierarchial Mean
#         - DB Scan
# - ReienForcement Learning
#     - eg : New Born Baby

# %% [markdown]
# ### Equation Of a Line, 3d-Plane and Hyper plane
# - y = mx+c
# - ax+by+c=0
# - slope : in unit movement in the x-axis what is the movement in the y-axis.
# - c - intercept if x =0 where the line will meet.
# - w1x1+w2x2+c =0
# - wTx + b=0 - Equation of a straight Line.
# - if line passing through the origin = wTx = 0
# - wTx = || w || * ||x|| * cos0 = 0
# - means cos is 0 when it is 90.
# - so, w is prependicular to the plane.

# %% [markdown]
# ### Instance- Based Vs model Based
# - Instance-Based
#     - Model Completely dependent on Training Data
#     - ![image.png](attachment:image.png)
#     - i will see the surrounding data and take the decisions.
#     - techniques
#         - KNN
#     - memorizing the data/by hearting the data.
#
# - Model-Based
#     - Understand the underlined Pattern from the data
#     - Create a Generaliation Method.
#     - ![image-2.png](attachment:image-2.png)
#     - Techniques.
#     - learning the data / pattern of the data.
#
# - ![image-3.png](attachment:image-3.png)
